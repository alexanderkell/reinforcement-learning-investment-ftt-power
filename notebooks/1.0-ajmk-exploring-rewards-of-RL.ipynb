# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
min_reward = pd.read_csv('data/run-DDPG_srv_2020-05-21_18-26-289tv41p5j-tag-ray_tune_episode_reward_min.csv')
max_reward = pd.read_csv('data/run-DDPG_srv_2020-05-21_18-26-289tv41p5j-tag-ray_tune_episode_reward_max.csv')
mean_reward = pd.read_csv('data/run-DDPG_srv_2020-05-21_18-26-289tv41p5j-tag-ray_tune_episode_reward_mean-2.csv')

# %%
# Cloud run
# mean_reward_2 = pd.read_csv('data/cloud-run/run-DDPG_srv_2020-05-21_18-26-289tv41p5j-tag-ray_tune_episode_reward_mean.csv')
# max_reward = pd.read_csv('data/run-DDPG_srv_2020-05-21_18-26-289tv41p5j-tag-ray_tune_episode_reward_max.csv')
# mean_reward = pd.read_csv('data/run-DDPG_srv_2020-05-21_18-26-289tv41p5j-tag-ray_tune_episode_reward_mean-2.csv')

# %%
def get_days_from_seconds(df):
    df['Run time'] = df['Wall time'] - df.iloc[0,0]
    df['Run time (days)'] = df['Run time']*(0.0000115741)
    return df

def set_type(df, type_of):
    df["Type"] = type_of
    return df

# %%
min_reward = get_days_from_seconds(min_reward)
max_reward = get_days_from_seconds(max_reward)
mean_reward = get_days_from_seconds(mean_reward)

min_reward = set_type(min_reward, "Minimum")
max_reward = set_type(max_reward, "Maximum")
mean_reward = set_type(mean_reward, "Mean")

# %%
all_df = [mean_reward, min_reward, max_reward]
pd.concat(all_df).to_csv("data/processed/training_data_all.csv")

# %%
sns.lineplot(data=min_reward[min_reward.Step>5000], x='Step', y='Value')
sns.lineplot(data=max_reward[max_reward.Step>5000], x='Step', y='Value')
sns.lineplot(data=mean_reward[mean_reward.Step>5000], x='Step', y='Value')

# %%
sns.lineplot(data=min_reward[min_reward.Step>5000], x='Run time (days)', y='Value')
sns.lineplot(data=max_reward[max_reward.Step>5000], x='Run time (days)', y='Value')
sns.lineplot(data=mean_reward[mean_reward.Step>5000], x='Run time (days)', y='Value')
# sns.regplot(data=mean_reward[mean_reward.Step>5000], x='Run time (days)', y='Value', line_kws={'color':"red"})

# %%
sns.lineplot(data=min_reward[min_reward['Step']>5000], x='Run time (days)', y='Value')
